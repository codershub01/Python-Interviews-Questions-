# %% [markdown]
# # Functions & Recursion

# %% [markdown]
# ## Write a recursive function for factorial.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

factorial(5)  # Output: 120
# Out:
# 120

# %% [markdown]
# ## Write recursive Fibonacci.

# %%
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

print([fibonacci(i) for i in range(8)])
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]

# %% [markdown]
# ## Explain difference between args and kwargs (coding example).

# %%
def example_args(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

example_args(1, 2, 3, name="Alice", age=25)

# %% [markdown]
# ## Write a function decorator.

# %%
def decorator(func):
    def wrapper():
        print("Before function call")
        func()
        print("After function call")
    return wrapper

@decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Before function call
# Hello!
# After function call

# %% [markdown]
# ## Write a lambda function to sort list of tuples.

# %%
data = [("apple", 5), ("banana", 2), ("cherry", 8)]
sorted_data = sorted(data, key=lambda x: x[1])
sorted_data
# Out:
# [('banana', 2), ('apple', 5), ('cherry', 8)]

# %% [markdown]
# ## Use map(), filter(), reduce() with example.

# %%
from functools import reduce

nums = [1, 2, 3, 4, 5]

# map() → square each number
squares = list(map(lambda x: x**2, nums))
print("Squares:", squares)

# filter() → keep only even numbers
evens = list(filter(lambda x: x % 2 == 0, nums))
print("Evens:", evens)

# reduce() → sum of all numbers
sum_nums = reduce(lambda x, y: x + y, nums)
print("Sum:", sum_nums)
